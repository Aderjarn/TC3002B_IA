# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/8° Semestre/IA M2 Benji/Dataset2_1"
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/8° Semestre/IA M2 Benji/Dataset2_1
# 'Copia de TestSavedModelASLTest.ipynb'	 ModelASL.ipynb       Test
#  External				 ModelASL.keras       TestSavedModelASLTest.ipynb
#  ModelASLImprovement.keras		 ModelASLTest.keras   Train

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = os.path.join('Train')
test_dir = os.path.join('Test')

class_names = sorted(os.listdir(train_dir))
class_labels = {
    'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9,
    'K': 10, 'L': 11, 'M': 12, 'N': 13, 'Nothing': 14, 'O': 15, 'P': 16, 'Q': 17,
    'R': 18, 'S': 19, 'Space': 20, 'T': 21, 'U': 22, 'V': 23, 'W': 24, 'X': 25,
    'Y': 26, 'Z': 27
}
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    preprocessing_function=tf.image.rgb_to_grayscale,
    validation_split=0.2
    )
validation_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=tf.image.rgb_to_grayscale
    )
test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=tf.image.rgb_to_grayscale
    )

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (64, 64),
    batch_size = 64,
    class_mode='sparse',
    subset='training',
    classes=class_names,
    shuffle=True,
    seed=42
    )
validation_generator = train_datagen.flow_from_directory(
    'Dataset2_1/Train',
    target_size=(64, 64),
    batch_size=64,
    class_mode='sparse',
    subset='validation',
    classes=class_names,
    shuffle=True,
    seed=42
    )
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(64, 64),
    batch_size=1,
    class_mode='sparse',
    classes=class_names,
    shuffle=False
    )
# Out:
# Found 22400 images belonging to 28 classes.
# Found 0 images belonging to 28 classes.
# Found 6900 images belonging to 28 classes.

# %%
new_model = tf.keras.models.load_model("ModelASLImprovement.keras")

# %%
# evaluate the model using images generated for test and the labels
num_test_samples = len(test_generator.filenames)
num_test_steps = num_test_samples // test_generator.batch_size

# Evaluate the model on the test data generator
test_loss, test_acc = new_model.evaluate(test_generator, steps=num_test_steps)
print('\nTest accuracy:', test_acc)
predictions = new_model.predict(test_generator)
predict_class = np.argmax(predictions, axis=1)
print('\nPredictClass:', predict_class.shape)
# Out:
# 6900/6900 [==============================] - 4831s 700ms/step - loss: 0.1166 - accuracy: 0.9681
#
# Test accuracy: 0.9681159257888794
# 6900/6900 [==============================] - 81s 12ms/step
#
# PredictClass: (6900,)

# %%
test_images = test_generator[0][0]
test_labels = test_generator[0][1]

# %%
predictions = new_model.predict(test_images)
classes_x = np.argmax(predictions,axis=1)
classes_x
# Out:
# 1/1 [==============================] - 0s 116ms/step
# array([0])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_labels = test_generator.classes

# Get the number of test samples
num_test_samples = len(test_generator.filenames)

# Get predictions for the entire test dataset
predictions = new_model.predict(test_generator, steps=num_test_samples // test_generator.batch_size + 1)

# Extract predicted labels
predicted_labels = np.argmax(predictions, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Visualization
plt.figure(figsize=(12, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predictions')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 6895/6901 [============================>.] - ETA: 0s
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6901 batches). You may need to use the repeat() function when building your dataset.
# 6901/6901 [==============================] - 81s 12ms/step

# %%
# Evaluate the model on the test data
loss, acc = new_model.evaluate(test_generator, verbose=2)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))

# Get predictions for the test data
predictions = new_model.predict(test_generator)

# Get the predicted classes
predicted_classes = np.argmax(predictions, axis=1)

# Print the shape of predictions
print("Shape of predictions:", predictions.shape)

# Retrieve true labels from the test generator
true_labels = test_generator.classes

# Print misidentified predictions
misidentified_indices = np.where(predicted_classes != true_labels)[0]
print("Misidentified indices:", misidentified_indices)

# Print misidentified predictions and their corresponding actual labels
print("Misidentified predictions:")
for index in misidentified_indices:
    print("Index:", index)
    print("Predicted class:", class_names[predicted_classes[index]])
    print("Actual class:", class_names[true_labels[index]])
# Out:
# 6900/6900 - 72s - loss: 0.1166 - accuracy: 0.9681 - 72s/epoch - 11ms/step
# Restored model, accuracy: 96.81%
# 6900/6900 [==============================] - 80s 12ms/step
# Shape of predictions: (6900, 28)
# Misidentified indices: [ 594  601  605  606  610  614  622  624  625  626  627  628  629  630
#   631  632  633  635  636  637  638  639  640  641  642  643  644  646
#   647  648  649 1985 1992 1994 2000 2012 2023 2045 2056 2067 2078 2100
#  2111 2112 2173 2184 2206 2217 2228 2868 2869 2870 2871 2872 2874 3381
#  3404 3405 3408 3409 3410 4697 4700 4712 4713 4714 4715 4716 4718 4719
#  4720 4721 4722 4723 4724 4725 4726 4727 4729 4730 4731 4732 4733 4734
#  4735 4736 4737 4738 4740 4741 4742 4743 4744 4745 4746 4747 4748 4749
#  4751 4752 4753 4754 4755 4756 4757 4758 4759 4760 4763 4764 4765 4766
#  4767 4768 4769 4770 4771 4772 4774 4775 4776 4777 4778 4779 4780 4782
#  4814 4815 4816 4818 5184 5206 5217 5228 5239 5250 5262 5273 5276 5284
#  5295 5306 5324 5325 5326 5327 5328 5329 5330 5331 5332 5333 5335 5336
#  5337 5338 5339 5341 5342 5343 5344 5346 5401 5412 5423 5434 5445 5456
#  5467 5478 5512 5523 5538 5539 5546 5547 5548 5549 5550 5551 5552 5553
#  5554 5558 5559 5560 5573 5584 5595 5606 5617 5628 5639 5650 5717 5773
#  5823 5889 6151 6213 6225 6226 6227 6230 6231 6245 6246 6247 6260 6270
#  6271 6274 6275 6276 6277 6279 6280 6281 6282 6314]
# Misidentified predictions:
# Index: 594
# Predicted class: D
# Actual class: C
# Index: 601
# Predicted class: D
# Actual class: C
# Index: 605
# Predicted class: D
# Actual class: C
# Index: 606
# Predicted class: D
# Actual class: C
# Index: 610
# Predicted class: D
# Actual class: C
# Index: 614
# Predicted class: D
# Actual class: C
# Index: 622
# Predicted class: D
# Actual class: C
# Index: 624
# Predicted class: D
# Actual class: C
# Index: 625
# Predicted class: D
# Actual class: C
# Index: 626
# Predicted class: D
# Actual class: C
# Index: 627
# Predicted class: D
# Actual class: C
# Index: 628
# Predicted class: D
# Actual class: C
# Index: 629
# Predicted class: D
# Actual class: C
# Index: 630
# Predicted class: D
# Actual class: C
# Index: 631
# Predicted class: D
# Actual class: C
# Index: 632
# Predicted class: D
# Actual class: C
# Index: 633
# Predicted class: D
# Actual class: C
# Index: 635
# Predicted class: D
# Actual class: C
# Index: 636
# Predicted class: D
# Actual class: C
# Index: 637
# Predicted class: D
# Actual class: C
# Index: 638
# Predicted class: D
# Actual class: C
# Index: 639
# Predicted class: D
# Actual class: C
# Index: 640
# Predicted class: D
# Actual class: C
# Index: 641
# Predicted class: D
# Actual class: C
# Index: 642
# Predicted class: D
# Actual class: C
# Index: 643
# Predicted class: D
# Actual class: C
# Index: 644
# Predicted class: D
# Actual class: C
# Index: 646
# Predicted class: D
# Actual class: C
# Index: 647
# Predicted class: D
# Actual class: C
# Index: 648
# Predicted class: D
# Actual class: C
# Index: 649
# Predicted class: D
# Actual class: C
# Index: 1985
# Predicted class: G
# Actual class: H
# Index: 1992
# Predicted class: Z
# Actual class: H
# Index: 1994
# Predicted class: Z
# Actual class: H
# Index: 2000
# Predicted class: L
# Actual class: I
# Index: 2012
# Predicted class: L
# Actual class: I
# Index: 2023
# Predicted class: L
# Actual class: I
# Index: 2045
# Predicted class: L
# Actual class: I
# Index: 2056
# Predicted class: L
# Actual class: I
# Index: 2067
# Predicted class: L
# Actual class: I
# Index: 2078
# Predicted class: L
# Actual class: I
# Index: 2100
# Predicted class: L
# Actual class: I
# Index: 2111
# Predicted class: L
# Actual class: I
# Index: 2112
# Predicted class: L
# Actual class: I
# Index: 2173
# Predicted class: L
# Actual class: I
# Index: 2184
# Predicted class: L
# Actual class: I
# Index: 2206
# Predicted class: L
# Actual class: I
# Index: 2217
# Predicted class: L
# Actual class: I
# Index: 2228
# Predicted class: L
# Actual class: I
# Index: 2868
# Predicted class: D
# Actual class: L
# Index: 2869
# Predicted class: D
# Actual class: L
# Index: 2870
# Predicted class: D
# Actual class: L
# Index: 2871
# Predicted class: D
# Actual class: L
# Index: 2872
# Predicted class: D
# Actual class: L
# Index: 2874
# Predicted class: D
# Actual class: L
# Index: 3381
# Predicted class: D
# Actual class: N
# Index: 3404
# Predicted class: D
# Actual class: N
# Index: 3405
# Predicted class: D
# Actual class: N
# Index: 3408
# Predicted class: D
# Actual class: N
# Index: 3409
# Predicted class: D
# Actual class: N
# Index: 3410
# Predicted class: D
# Actual class: N
# Index: 4697
# Predicted class: X
# Actual class: S
# Index: 4700
# Predicted class: X
# Actual class: S
# Index: 4712
# Predicted class: X
# Actual class: S
# Index: 4713
# Predicted class: X
# Actual class: S
# Index: 4714
# Predicted class: X
# Actual class: S
# Index: 4715
# Predicted class: X
# Actual class: S
# Index: 4716
# Predicted class: X
# Actual class: S
# Index: 4718
# Predicted class: X
# Actual class: S
# Index: 4719
# Predicted class: J
# Actual class: S
# Index: 4720
# Predicted class: J
# Actual class: S
# Index: 4721
# Predicted class: J
# Actual class: S
# Index: 4722
# Predicted class: J
# Actual class: S
# Index: 4723
# Predicted class: J
# Actual class: S
# Index: 4724
# Predicted class: J
# Actual class: S
# Index: 4725
# Predicted class: J
# Actual class: S
# Index: 4726
# Predicted class: J
# Actual class: S
# Index: 4727
# Predicted class: J
# Actual class: S
# Index: 4729
# Predicted class: J
# Actual class: S
# Index: 4730
# Predicted class: J
# Actual class: S
# Index: 4731
# Predicted class: J
# Actual class: S
# Index: 4732
# Predicted class: J
# Actual class: S
# Index: 4733
# Predicted class: J
# Actual class: S
# Index: 4734
# Predicted class: J
# Actual class: S
# Index: 4735
# Predicted class: J
# Actual class: S
# Index: 4736
# Predicted class: J
# Actual class: S
# Index: 4737
# Predicted class: J
# Actual class: S
# Index: 4738
# Predicted class: J
# Actual class: S
# Index: 4740
# Predicted class: J
# Actual class: S
# Index: 4741
# Predicted class: J
# Actual class: S
# Index: 4742
# Predicted class: J
# Actual class: S
# Index: 4743
# Predicted class: J
# Actual class: S
# Index: 4744
# Predicted class: J
# Actual class: S
# Index: 4745
# Predicted class: J
# Actual class: S
# Index: 4746
# Predicted class: J
# Actual class: S
# Index: 4747
# Predicted class: J
# Actual class: S
# Index: 4748
# Predicted class: J
# Actual class: S
# Index: 4749
# Predicted class: J
# Actual class: S
# Index: 4751
# Predicted class: J
# Actual class: S
# Index: 4752
# Predicted class: J
# Actual class: S
# Index: 4753
# Predicted class: J
# Actual class: S
# Index: 4754
# Predicted class: J
# Actual class: S
# Index: 4755
# Predicted class: J
# Actual class: S
# Index: 4756
# Predicted class: J
# Actual class: S
# Index: 4757
# Predicted class: J
# Actual class: S
# Index: 4758
# Predicted class: J
# Actual class: S
# Index: 4759
# Predicted class: J
# Actual class: S
# Index: 4760
# Predicted class: J
# Actual class: S
# Index: 4763
# Predicted class: J
# Actual class: S
# Index: 4764
# Predicted class: J
# Actual class: S
# Index: 4765
# Predicted class: J
# Actual class: S
# Index: 4766
# Predicted class: J
# Actual class: S
# Index: 4767
# Predicted class: J
# Actual class: S
# Index: 4768
# Predicted class: J
# Actual class: S
# Index: 4769
# Predicted class: J
# Actual class: S
# Index: 4770
# Predicted class: J
# Actual class: S
# Index: 4771
# Predicted class: J
# Actual class: S
# Index: 4772
# Predicted class: J
# Actual class: S
# Index: 4774
# Predicted class: J
# Actual class: S
# Index: 4775
# Predicted class: J
# Actual class: S
# Index: 4776
# Predicted class: J
# Actual class: S
# Index: 4777
# Predicted class: J
# Actual class: S
# Index: 4778
# Predicted class: J
# Actual class: S
# Index: 4779
# Predicted class: J
# Actual class: S
# Index: 4780
# Predicted class: J
# Actual class: S
# Index: 4782
# Predicted class: J
# Actual class: S
# Index: 4814
# Predicted class: A
# Actual class: S
# Index: 4815
# Predicted class: A
# Actual class: S
# Index: 4816
# Predicted class: A
# Actual class: S
# Index: 4818
# Predicted class: A
# Actual class: S
# Index: 5184
# Predicted class: Y
# Actual class: T
# Index: 5206
# Predicted class: Y
# Actual class: T
# Index: 5217
# Predicted class: Y
# Actual class: T
# Index: 5228
# Predicted class: Y
# Actual class: T
# Index: 5239
# Predicted class: Y
# Actual class: T
# Index: 5250
# Predicted class: Y
# Actual class: T
# Index: 5262
# Predicted class: Y
# Actual class: T
# Index: 5273
# Predicted class: Y
# Actual class: T
# Index: 5276
# Predicted class: A
# Actual class: T
# Index: 5284
# Predicted class: Y
# Actual class: T
# Index: 5295
# Predicted class: Y
# Actual class: T
# Index: 5306
# Predicted class: Y
# Actual class: T
# Index: 5324
# Predicted class: Y
# Actual class: T
# Index: 5325
# Predicted class: Y
# Actual class: T
# Index: 5326
# Predicted class: Y
# Actual class: T
# Index: 5327
# Predicted class: Y
# Actual class: T
# Index: 5328
# Predicted class: Y
# Actual class: T
# Index: 5329
# Predicted class: Y
# Actual class: T
# Index: 5330
# Predicted class: Y
# Actual class: T
# Index: 5331
# Predicted class: Y
# Actual class: T
# Index: 5332
# Predicted class: Y
# Actual class: T
# Index: 5333
# Predicted class: Y
# Actual class: T
# Index: 5335
# Predicted class: J
# Actual class: T
# Index: 5336
# Predicted class: Y
# Actual class: T
# Index: 5337
# Predicted class: Y
# Actual class: T
# Index: 5338
# Predicted class: J
# Actual class: T
# Index: 5339
# Predicted class: Y
# Actual class: T
# Index: 5341
# Predicted class: J
# Actual class: T
# Index: 5342
# Predicted class: J
# Actual class: T
# Index: 5343
# Predicted class: J
# Actual class: T
# Index: 5344
# Predicted class: J
# Actual class: T
# Index: 5346
# Predicted class: J
# Actual class: T
# Index: 5401
# Predicted class: R
# Actual class: U
# Index: 5412
# Predicted class: R
# Actual class: U
# Index: 5423
# Predicted class: R
# Actual class: U
# Index: 5434
# Predicted class: R
# Actual class: U
# Index: 5445
# Predicted class: R
# Actual class: U
# Index: 5456
# Predicted class: R
# Actual class: U
# Index: 5467
# Predicted class: R
# Actual class: U
# Index: 5478
# Predicted class: R
# Actual class: U
# Index: 5512
# Predicted class: R
# Actual class: U
# Index: 5523
# Predicted class: R
# Actual class: U
# Index: 5538
# Predicted class: R
# Actual class: U
# Index: 5539
# Predicted class: R
# Actual class: U
# Index: 5546
# Predicted class: R
# Actual class: U
# Index: 5547
# Predicted class: R
# Actual class: U
# Index: 5548
# Predicted class: R
# Actual class: U
# Index: 5549
# Predicted class: R
# Actual class: U
# Index: 5550
# Predicted class: R
# Actual class: U
# Index: 5551
# Predicted class: R
# Actual class: U
# Index: 5552
# Predicted class: R
# Actual class: U
# Index: 5553
# Predicted class: R
# Actual class: U
# Index: 5554
# Predicted class: R
# Actual class: U
# Index: 5558
# Predicted class: R
# Actual class: U
# Index: 5559
# Predicted class: R
# Actual class: U
# Index: 5560
# Predicted class: R
# Actual class: U
# Index: 5573
# Predicted class: R
# Actual class: U
# Index: 5584
# Predicted class: R
# Actual class: U
# Index: 5595
# Predicted class: R
# Actual class: U
# Index: 5606
# Predicted class: R
# Actual class: U
# Index: 5617
# Predicted class: R
# Actual class: U
# Index: 5628
# Predicted class: R
# Actual class: U
# Index: 5639
# Predicted class: R
# Actual class: U
# Index: 5650
# Predicted class: W
# Actual class: V
# Index: 5717
# Predicted class: W
# Actual class: V
# Index: 5773
# Predicted class: W
# Actual class: V
# Index: 5823
# Predicted class: W
# Actual class: V
# Index: 5889
# Predicted class: W
# Actual class: V
# Index: 6151
# Predicted class: I
# Actual class: X
# Index: 6213
# Predicted class: I
# Actual class: X
# Index: 6225
# Predicted class: I
# Actual class: X
# Index: 6226
# Predicted class: I
# Actual class: X
# Index: 6227
# Predicted class: I
# Actual class: X
# Index: 6230
# Predicted class: I
# Actual class: X
# Index: 6231
# Predicted class: I
# Actual class: X
# Index: 6245
# Predicted class: I
# Actual class: X
# Index: 6246
# Predicted class: I
# Actual class: X
# Index: 6247
# Predicted class: I
# Actual class: X
# Index: 6260
# Predicted class: I
# Actual class: X
# Index: 6270
# Predicted class: I
# Actual class: X
# Index: 6271
# Predicted class: I
# Actual class: X
# Index: 6274
# Predicted class: I
# Actual class: X
# Index: 6275
# Predicted class: I
# Actual class: X
# Index: 6276
# Predicted class: I
# Actual class: X
# Index: 6277
# Predicted class: I
# Actual class: X
# Index: 6279
# Predicted class: I
# Actual class: X
# Index: 6280
# Predicted class: I
# Actual class: X
# Index: 6281
# Predicted class: I
# Actual class: X
# Index: 6282
# Predicted class: I
# Actual class: X
# Index: 6314
# Predicted class: I
# Actual class: X

# %%
def plot_images_with_predictions(num_images):
    plt.figure(figsize=(10 * num_cols, 2 * num_rows))
    images_shown = 0

    for batch_images, batch_labels in test_generator:
        # Get predictions for the entire batch
        batch_predictions = new_model.predict(batch_images)

        for i in range(len(batch_labels)):
            plt.subplot(num_rows, 2 * num_cols, 2 * images_shown + 1)
            plot_image(i, batch_predictions[i], batch_labels, batch_images)
            plt.subplot(num_rows, 2 * num_cols, 2 * images_shown + 2)
            plot_value_array(i, batch_predictions[i], batch_labels)

            images_shown += 1
            if images_shown >= num_images:
                break

        if images_shown >= num_images:
            break

    plt.tight_layout()
    plt.show()

def plot_image(i, predictions_array, true_label, img):
    true_label = int(true_label[i])  # Convert true_label to integer
    img = img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                          100*np.max(predictions_array),
                                          class_names[true_label]),
                                          color=color)

# Define plot_value_array function
def plot_value_array(i, predictions_array, true_label):
    true_label = int(true_label[i])  # Convert true_label to integer
    plt.grid(False)
    plt.xticks(range(len(class_names)))
    plt.yticks([])
    thisplot = plt.bar(range(len(class_names)), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = 8
plot_images_with_predictions(num_images)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
plt.figure(figsize=(15, 15))
class_indices = {class_label: [] for class_label in range(len(class_names))}

# Gather indices of images for each class
for i, label in enumerate(predict_class):
    class_indices[label].append(i)
for i, class_label in enumerate(class_indices):
    # Get the index of the first image for the current class
    image_batch_index = class_indices[class_label][0] // test_generator.batch_size
    image_index_in_batch = class_indices[class_label][0] % test_generator.batch_size

    # Retrieve the batch of images
    batch_images, _ = test_generator[image_batch_index]

    # Predictions for the entire batch
    batch_predictions = new_model.predict(batch_images)

    # Plot the image
    plt.subplot(5, 6, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(batch_images[image_index_in_batch], cmap=plt.cm.binary)

    # Get the predicted label for the first image in the batch
    predicted_label = np.argmax(batch_predictions[image_index_in_batch])

    plt.xlabel("True: {} \nPredicted: {}".format(
        class_names[test_generator.classes[image_batch_index * test_generator.batch_size + image_index_in_batch]],
        class_names[predicted_label]))

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
external_dir = os.path.join('External')
ext_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=tf.image.rgb_to_grayscale
    )
ext_generator = ext_datagen.flow_from_directory(
    external_dir,
    target_size=(64, 64),
    batch_size=1,
    class_mode='sparse',
    shuffle=False
    )
# Out:
# Found 17 images belonging to 28 classes.

# %%
# Predict classes for external images using ext_generator
external_predictions = new_model.predict(ext_generator)

# Map predicted class indices to class names
predicted_class_names = [class_names[np.argmax(prediction)] for prediction in external_predictions]
# Out:
# 17/17 [==============================] - 12s 776ms/step

# %%
def display_external_images_with_predictions(generator, predictions, true_labels, class_names):
    plt.figure(figsize=(15, 15))
    num_images = len(predictions)

    for i in range(num_images):
        image = generator[i][0]  # Access the images from the generator
        predicted_class_index = np.argmax(predictions[i])
        predicted_class_name = class_names[predicted_class_index]
        true_class_index = true_labels[i]
        true_class_name = class_names[true_class_index]

        plt.subplot(5, 6, i + 1)
        plt.imshow(image.squeeze(), cmap='gray')  # Squeeze to remove the channel dimension if present
        plt.title("True class: {}\nPredicted class: {}".format(true_class_name, predicted_class_name))
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Display external images with their predicted and true classes
display_external_images_with_predictions(ext_generator, external_predictions, ext_generator.classes, class_names)
